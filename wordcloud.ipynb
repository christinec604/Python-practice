# %% [markdown]
# <a href="https://colab.research.google.com/github/christinec604/Python-practice/blob/main/wordcloud.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ls '/content/drive/MyDrive/Colab Notebooks/TED'
# Out:
# '2011pos Older people are happier.txt'
# "2012neg What doctors don't know about the drugs they prescribe.txt"
# '2016neu Asking for help is a strength, not a weakness.txt'

# %%
ls "/content/drive/MyDrive/Colab Notebooks/TED"
# Out:
# '2011pos Older people are happier.txt'
# "2012neg What doctors don't know about the drugs they prescribe.txt"
# '2016neu Asking for help is a strength, not a weakness.txt'

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

#讀取文本
f = open('/content/drive/MyDrive/Colab Notebooks/TED/2011pos Older people are happier.txt','r').read()


# background_color 背景顏色
# width 寬
# height 高
# margin 圖片邊緣
# max_font_size 設定文字中最大的大小是多少
# min_font_size
# max_words  文字雲顯示最大詞數
# font_path="/tmp/DFFT_C7.ttc", #設置字體

wordcloud = WordCloud(
    background_color="blue",
    width=2000,
    height=1000,
    margin= 10,
    max_words=1000
).generate(f)


plt.imshow(wordcloud)
plt.axis("off")
plt.show()

# %%
from wordcloud import STOPWORDS
print(STOPWORDS)
# Out:
# {'between', 'where', 'did', 'having', "weren't", 'does', 'an', "aren't", 'get', 'ourselves', 'we', 'both', 'itself', 'his', "she'll", 'himself', 'each', 'and', "here's", 'however', 'otherwise', "we've", 'those', 'should', 'whom', 'what', 'further', 'by', 'no', "they're", "couldn't", 'from', "won't", "wasn't", 'against', 'with', 'themselves', "he'll", "mustn't", 'through', 'why', "we'd", 'same', 'them', 'but', 'can', 'some', 'off', "isn't", 'this', 'when', 'just', "shouldn't", 'these', 'out', "let's", 'were', "she's", 'which', 'on', 'after', 'been', 'a', "it's", 'because', 'doing', 'if', "they'd", "why's", 'am', 'cannot', 'you', 'hers', 'the', "what's", 'about', "haven't", 'herself', 'while', 'has', 'over', "they'll", 'to', 'here', "wouldn't", "she'd", 'ours', 'how', 'are', 'or', 'under', "how's", 'nor', "when's", 'all', 'yours', 'my', 'her', 'very', 'www', "i'll", 'shall', 'who', 'would', 'was', 'http', 'until', "you've", 'yourself', 'therefore', 'in', 'most', "we're", "you'd", "didn
# ...

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

#讀取文本
f = open('/content/drive/MyDrive/Colab Notebooks/TED/2011pos Older people are happier.txt','r').read()

# stopwords 停用字詞
stop = ["people", "old people", "time", "life"] + list(STOPWORDS)

wordcloud = WordCloud(
    background_color="white",
    width=1500,
    height=1000,
    margin=2,
    stopwords=stop
).generate(f)


plt.imshow(wordcloud)
plt.axis("off")
plt.show()
